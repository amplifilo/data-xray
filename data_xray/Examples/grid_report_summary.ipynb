# %%
# %load_ext autoreload
# %autoreload 2

# %%
'''import functions'''

from data_xray.file_io import FindScans, FindData, FindGrids
from data_xray.modules import *
from data_xray.report import SummaryPPT
import sys
import os

# %%
dir = "/Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/"

# %%
imageFiles = FindData(topdir=dir, ext='sxm', get_data=True, header_only=True);
# Out:
# 100%|██████████| 1015/1015 [00:02<00:00, 441.69it/s]

# %%
imageFiles[0].fname
# Out:
# '/Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20211222_FeSe_77K/cu111_77K0001.sxm'

# %%
gridFiles = FindData(topdir=dir, ext='3ds', get_data=True, header_only=True);
# Out:
#  62%|██████▎   | 10/16 [00:00<00:00, 75.57it/s]
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy001.3ds
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy001.3ds imported
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy002.3ds
# something wrong with sweep signal 2
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy002.3ds failed
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy003.3ds
# something wrong with sweep signal 2
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy003.3ds failed
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy004.3ds
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy004.3ds imported
# ...

# %%
[print(str(os.path.getsize(g)/1e6) + ' Mb .....' + g) for g in grids];
# Out:
# 1.786537 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy001.3ds
# 0.005901 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy002.3ds
# 0.016405 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy003.3ds
# 0.049531 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy004.3ds
# 9.794317 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy006.3ds
# 0.0517 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220115_FeSe(3_1)_STM_4.3K/Grid Spectroscopy001.3ds
# 8.28106 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220115_FeSe(3_1)_STM_4.3K/Grid Spectroscopy002.3ds
# 26.477193 Mb ...../Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy005.3ds
# ...

# %%
gridFiles[0].fname
# Out:
# '/Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy001.3ds'

# %%
SummaryPPT(pname="grid_summary", fdict = gridFiles, chanselect= {'grid' : 'cf'})
# Out:
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy001.3ds
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy001.3ds imported
# Grid Spectroscopy001.3ds imported
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy002.3ds
# something wrong with sweep signal 2
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy002.3ds failed
# Grid Spectroscopy002.3ds import into ppt failed
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy003.3ds
# something wrong with sweep signal 2
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy003.3ds failed
# Grid Spectroscopy003.3ds import into ppt failed
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220108_FeSe(4)_STM_4.3K/Grid Spectroscopy004.3ds
# ...

# %%
from data_xray.nanonisio import Grid
from data_xray.grid.dsops import grid_viz
import inspect

# %%
inspect.getmembers(grid_viz, predicate=inspect.ismethod)
# Out:
# [('chan_derivative',
#   <bound method grid_viz.chan_derivative of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('chan_histogram',
#   <bound method grid_viz.chan_histogram of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('chan_method',
#   <bound method grid_viz.chan_method of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('chan_mod',
#   <bound method grid_viz.chan_mod of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('chan_pca_denoise',
#   <bound method grid_viz.chan_pca_denoise of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('chan_pca_kmeans',
#   <bound method grid_viz.chan_pca_kmeans of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('find_index',
#   <bound method grid_viz.find_index of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('get_bias_index',
#   <bound method grid_viz.get_bias_index of <class 'data_xray.grid.dsops.grid_viz'>>),
#  ('substract_current_offset',
#   <bound method grid_viz.substract_current_offset of <class 'data_xray.grid.dsops.grid_viz'>>),
# ...

# %%
grid_viz.chan_pca_kmeans(ds2.ds, chan='cf', comps=3 )
# Out:
# array([[2, 3, 3, ..., 3, 3, 3],
#        [1, 2, 3, ..., 3, 0, 2],
#        [2, 1, 0, ..., 2, 0, 0],
#        ...,
#        [0, 3, 3, ..., 2, 3, 0],
#        [2, 2, 0, ..., 3, 2, 0],
#        [3, 2, 0, ..., 0, 3, 3]], dtype=int32)

# %%
from matplotlib import pyplot as plt

# %%
f,a = pplt.subplots()
grid_viz.chan_histogram(ds2.ds, xy=['bias', 'cf'], ax=a)
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %%
ds2.ds.attrs['size_xy']
# Out:
# [2e-07, 2e-07]

# %%
grid_viz.chan_histogram()

# %%
large_grid = [g for g in grids if os.path.getsize(g)/1e6 > 10];
ds2 = Grid(large_grid[-1])
# Out:
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220124_FeSe_4.3K/Grid Spectroscopy005.3ds
# /Users/5nm/Dropbox (ORNL)/SangYong/00 JTSTMdata/20220124_FeSe_4.3K/Grid Spectroscopy005.3ds imported

# %%
ds2.ds.attrs['start_time']
# Out:
# '24.01.2022 20:23:34'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-8689fc9f52d0> in <module>
# ----> 1 SummaryPPT(pname="grid_summary", fdict = grids, chanselect= {'grid' : 'cf'})
#
# ~/Documents/GitHub/data-xray/data_xray/report/core.py in __init__(self, pname, new, fdict, group_sequences, maximages, chanselect, **kwargs)
#      32             fdicts = [fdict[i:i + maximages] for i in range(0, len(fdict), maximages)]
#      33
# ---> 34         self.topdir = os.path.commonpath([j.header['fname'] for j in fdict]) + '/'
#      35         self.chanselect = chanselect
#      36         for j,f in enumerate(fdicts):
#
# ~/Documents/GitHub/data-xray/data_xray/report/core.py in <listcomp>(.0)
#      32             fdicts = [fdict[i:i + maximages] for i in range(0, len(fdict), maximages)]
#      33
# ...

# %%
class hello2:
    def __init__(self, p2=0):
        self.p2 = 5
    
    @classmethod
    def print_parm(cls):
        print('here')
        print(cls.__dict__.keys())

# %%
hello2().print_parm()
# Out:
# here
# dict_keys(['__module__', '__init__', 'print_parm', '__dict__', '__weakref__', '__doc__'])

# %%
a2 = hello2()

# %%
a2.print_parm()
# Out:
# here
# dict_keys(['__module__', '__init__', 'print_parm', '__dict__', '__weakref__', '__doc__'])
